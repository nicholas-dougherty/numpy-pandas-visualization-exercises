# %% [markdown]
# For several of the following exercises, you'll need to load several datasets using the pydataset library.
#
# * _(If you get an error when trying to run the import below, use pip to install the pydataset package.)_

# %%
from pydataset import data

# %% [markdown]
# When the instructions say to load a dataset,
# you can pass the name of the dataset as a string
# to the data function to load the dataset.
#
# You can also view the documentation for the data set
# by passing the show_doc keyword argument.
#
# __data('mpg', show_doc=True)__ # view the documentation for the dataset
#
# __mpg = data('mpg')__  # load the dataset and store it in a variable

# %% [markdown]
# #### 1.) Copy the code from the lesson to create a dataframe full of student grades.

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

type(df)

grades = df

# %%
print(grades)
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
grades
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %%
grades.describe()
# Out:
#             math    english    reading
# count  12.000000  12.000000  12.000000
# mean   84.833333  77.666667  86.500000
# std    11.134168  13.371158   9.643651
# min    62.000000  62.000000  67.000000
# 25%    78.500000  63.750000  80.750000
# 50%    90.000000  77.500000  89.000000
# 75%    92.250000  86.750000  93.250000
# max    98.000000  99.000000  98.000000

# %%
grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     12 non-null     object
#  1   math     12 non-null     int64
#  2   english  12 non-null     int64
#  3   reading  12 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 512.0+ bytes

# %% [markdown]
# a.) Create a column named passing_english that indicates
# whether each student has a passing grade in english.

# %%
grades['passing_english'] = grades.english >= 70
grades
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %% [markdown]
# b.) Sort the english grades by the passing_english column.
# How are duplicates handled?

# %%
grades.sort_values(by='passing_english')
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# Duplicates are treated separately and arranged in ascending order by their index number.

# %% [markdown]
# c.)
# * Sort the english grades first by passing_english
# and then by student name.
# * All the students that are failing english should be first,
# and within the students that are failing english they
# should be ordered alphabetically.
# * The same should be true for the students passing english.
# -
# _(Hint: you can pass a list to the .sort_values method)_

# %%
grades.sort_values(by = ['passing_english', 'name'])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# d.) Sort the english grades first by passing_english, and
# then by the actual english grade, similar to how we did in
# the last step.

# %%
grades.sort_values(by = ['passing_english', 'english'])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# e.) Calculate each students overall grade and
# add it as a column on the dataframe.
# The overall grade is the average of the math,
# english, and reading grades.

# %%
grades['overall_grade'] = 
grades
# Out:
#   File "/var/folders/qn/sd1_3x2j4196db03067vql600000gn/T/ipykernel_1354/2139028234.py", line 1
#     grades['overall_grade'] =
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# -_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_

# %% [markdown]
# #### 2.) Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
data('mpg')  
mpg = data('mpg') # load the dataset and store it in a variable

# %% [markdown]
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# #### Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ##### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# #### Usage
#
#     data(mpg)
#
# #### Format
#
# A data frame with 234 rows and 11 variables
#
# #### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# How many rows and columns are there?

# %%
mpg
# 234 rows and 11 columns
# Out:
#     manufacturer   model  displ  year  cyl  ... drv cty  hwy  fl    class
# 1           audi      a4    1.8  1999    4  ...   f  18   29   p  compact
# 2           audi      a4    1.8  1999    4  ...   f  21   29   p  compact
# 3           audi      a4    2.0  2008    4  ...   f  20   31   p  compact
# 4           audi      a4    2.0  2008    4  ...   f  21   30   p  compact
# 5           audi      a4    2.8  1999    6  ...   f  16   26   p  compact
# ..           ...     ...    ...   ...  ...  ...  ..  ..  ...  ..      ...
# 230   volkswagen  passat    2.0  2008    4  ...   f  19   28   p  midsize
# 231   volkswagen  passat    2.0  2008    4  ...   f  21   29   p  midsize
# 232   volkswagen  passat    2.8  1999    6  ...   f  16   26   p  midsize
# 233   volkswagen  passat    2.8  1999    6  ...   f  18   26   p  midsize
# 234   volkswagen  passat    3.6  2008    6  ...   f  17   26   p  midsize
#
# [234 rows x 11 columns]

# %%
#another way to reach this answer:
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Rename the cty column to city.

# %%
mpg = mpg.rename(columns={'cty': 'city'})

# %% [markdown]
# Rename the hwy column to highway.

# %%
mpg = mpg.rename(columns={'hwy': 'highway'})

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg['city exceeds highway'] = 'city' > 'highway'
mpg.sort_values(by='city exceeds highway', ascending=False)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  city  \
# 1           audi               a4    1.8  1999    4    auto(l5)   f    18
# 161       subaru     forester awd    2.5  1999    4    auto(l4)   4    18
# 149       nissan           maxima    3.0  1999    6  manual(m5)   f    19
# 150       nissan           maxima    3.5  2008    6    auto(av)   f    19
# 151       nissan   pathfinder 4wd    3.3  1999    6    auto(l4)   4    14
# ..           ...              ...    ...   ...  ...         ...  ..   ...
# 83          ford     explorer 4wd    5.0  1999    8    auto(l4)   4    13
# 84          ford  f150 pickup 4wd    4.2  1999    6    auto(l4)   4    14
# 85          ford  f150 pickup 4wd    4.2  1999    6  manual(m5)   4    14
# 86          ford  f150 pickup 4wd    4.6  1999    8  manual(m5)   4    13
# 234   volkswagen           passat    3.6  2008    6    auto(s6)   f    17
#
#      highway fl    class  city exceeds highway
# ...

# %%
#alternatively, 
mpg[mpg.city > mpg.highway]
# this returns zero rows.
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class, city exceeds highway]
# Index: []

# %% [markdown]
# Create a column named mileage_difference this column should
# contain the difference between highway and city mileage for each car.

# %%
# mpg['mileage_difference'] = np.subtract('highway', 'city')
# np.subtract(mpg[mpg.highway, mpg.city]) couldn't get numpy to work..

mpg['mileage_difference'] = mpg.highway - mpg.city 
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg.mileage_difference.max()
mpg[mpg.mileage_difference == mpg.mileage_difference.max()]

# Honda Civic & Volkwagen New Beetle
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  city exceeds highway  mileage_difference
# 107  c  subcompact                 False                  12
# 223  d  subcompact                 False                  12

# %% [markdown]
# Which compact class car has the lowest highway mileage?
# The best?

# %%
compact = mpg[mpg['class'] == 'compact']

# %% [markdown]
# Create a column named average_mileage that is
# the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = mpg[['city', 'highway']].mean()
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# Which dodge car has the best average mileage?
# The worst?

# %% [markdown]
# #### 3.) Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %% [markdown]
# How many rows and columns are there?

# %% [markdown]
# What are the data types?

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %% [markdown]
# What is the the weight of the fastest animal?

# %% [markdown]
# What is the overall percentage of specials?

# %% [markdown]
# How many animals are hoppers that are above the median speed?
# What percentage is this?
